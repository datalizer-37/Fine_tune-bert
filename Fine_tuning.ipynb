# %%
import pandas as pd

# Load data from Excel into a Pandas DataFrame
file_path = '/content/omega_cleaned.csv'  # Adjust the path as per your file location
df = pd.read_csv(file_path)

# %%
df.head(20)
# Out:
#     Value Date ChequeNo.                                        Description  \
# 0   27/02/2021         -  NEFT-N058211420157383-MURUGESAN C-LUKER-\n5020...
# 1   27/02/2021         -  MMT/IMPS/105809933588/7k/N ASHOK KU to SHREE SAPT
# 2   28/02/2021         -       MMT/IMPS/105916313747/SELVAKUMAR/Canara Bank
# 3   28/02/2021         -  NEFT-SBIN421059077319-AVR SWARNA MAHAL JEWELRY...
# 4   28/02/2021         -  NEFT-CIUBH21059004611-EDAPPADI MURUGAPPA\nENTE...
# 5   01/03/2021         -  UPI/106009173923/UPI/srinivasan27rs@/State Ban...
# 6   01/03/2021         -                BY CASH  - SALEM - AGRAHARAM STREET
# 7   01/03/2021         -          CLG/S K ENTERPRISES/166577/AXI/26.02.2021
# 8   01/03/2021         -          CLG/G M ENTERPRISES/544512/SYB/26.02.2021
# 9   01/03/2021         -           CLG/ARROW VENTURES/090886/AXI/25.02.2021
# 10  01/03/2021         -  NEFT-N060210079338804-GALAXY 7   CO-1622-\n162...
# ...

# %%
  #column_to_drop = 'Unnamed: 5'
  #if column_to_drop in df.columns:
    #  df.drop([column_to_drop], axis=1, inplace=True)
     # print(f"Column '{column_to_drop}' dropped successfully.")
  #else:
   #   print(f"Column '{column_to_drop}' not found in the DataFrame.")

  #df.head()

# %%
df['classification'] = df['classification'].map({'Expense': 0, 'Income': 1})

# %%
df['Description'] = df['Description'].astype(str)

# %%
df['Description'].dtype
# Out:
# dtype('O')

# %%
df.head(15)
# Out:
#     Value Date ChequeNo.                                        Description  \
# 0   27/02/2021         -  NEFT-N058211420157383-MURUGESAN C-LUKER-\n5020...
# 1   27/02/2021         -  MMT/IMPS/105809933588/7k/N ASHOK KU to SHREE SAPT
# 2   28/02/2021         -       MMT/IMPS/105916313747/SELVAKUMAR/Canara Bank
# 3   28/02/2021         -  NEFT-SBIN421059077319-AVR SWARNA MAHAL JEWELRY...
# 4   28/02/2021         -  NEFT-CIUBH21059004611-EDAPPADI MURUGAPPA\nENTE...
# 5   01/03/2021         -  UPI/106009173923/UPI/srinivasan27rs@/State Ban...
# 6   01/03/2021         -                BY CASH  - SALEM - AGRAHARAM STREET
# 7   01/03/2021         -          CLG/S K ENTERPRISES/166577/AXI/26.02.2021
# 8   01/03/2021         -          CLG/G M ENTERPRISES/544512/SYB/26.02.2021
# 9   01/03/2021         -           CLG/ARROW VENTURES/090886/AXI/25.02.2021
# 10  01/03/2021         -  NEFT-N060210079338804-GALAXY 7   CO-1622-\n162...
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
import torch
from transformers import TrainingArguments, Trainer
from transformers import BertTokenizer, BertForSequenceClassification

# %%
from transformers import BertTokenizer, BertForSequenceClassification
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased',num_labels=2)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model = model.to('cuda')

# %%
X = list(df["Description"])
y = list(df["classification"])
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)
X_train_tokenized = tokenizer(X_train, padding=True, truncation=True, max_length=512)
X_val_tokenized = tokenizer(X_val, padding=True, truncation=True, max_length=512)

# %%
len(X_train),len(X_val)
# Out:
# (15862, 3966)

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels=None):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        if self.labels is not None:
            item["labels"] = torch.tensor(self.labels[idx], dtype=torch.long)
        return item

    def __len__(self):
        return len(self.encodings["input_ids"])

# %%
train_dataset = Dataset(X_train_tokenized, y_train)
val_dataset = Dataset(X_val_tokenized, y_val)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# %%
def compute_metrics(p):
    print(type(p))
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    recall = recall_score(y_true=labels, y_pred=pred)
    precision = precision_score(y_true=labels, y_pred=pred)
    f1 = f1_score(y_true=labels, y_pred=pred)

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}

# %%
#!pip install transformers datasets
import torch
from transformers import AutoModelForSequenceClassification

# Assuming your model is named 'model'
num_labels = 2 # Assuming you want a single output value
model = AutoModelForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=num_labels)

# Add a linear layer
classifier = torch.nn.Linear(model.config.hidden_size, num_labels) # Create a linear layer
model.classifier = classifier # Replace the existing classifier with the new one
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
args = TrainingArguments(
    output_dir="output",
    num_train_epochs=4,
    per_device_train_batch_size=1

)
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics
)

# %%
from transformers import TrainingArguments, Trainer

args = TrainingArguments(
    output_dir="output",
    num_train_epochs=4,
    per_device_train_batch_size=1,
    learning_rate=5e-5,  # Set the learning rate here
    weight_decay=0.01,  # Optional: Add weight decay if needed
    logging_dir='./logs',  # Optional: Directory for storing logs
    logging_steps=500,  # Optional: Frequency of logging
)

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='21001' max='63448' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [21001/63448 40:07 < 1:21:06, 8.72 it/s, Epoch 1.32/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.262300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.497400</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.476800</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.514000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.529300</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.570700</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>1.540000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.627600</td>
#     </tr>
#     <tr>
#       <td>4500</td>
# ...

# %%
trainer.evaluate()

# %%
from transformers import Trainer

# Define the directory where you want to save your fine-tuned model
output_dir = "bsa"

# Save the fine-tuned model
trainer.save_model(output_dir)
tokenizer.save_pretrained(output_dir)

print(f"Fine-tuned model and tokenizer saved to {output_dir}")

# %%
from transformers import BertTokenizer, BertForSequenceClassification

# Load the saved model and tokenizer
model_path = '/content/bsa'
model = BertForSequenceClassification.from_pretrained(model_path)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
inputs = tokenizer(df['Description'].tolist(), padding=True, truncation=True, max_length=512, return_tensors='pt')

# %%
import torch

model.eval()
with torch.no_grad():
    outputs = model(**inputs)
    predictions = torch.argmax(outputs.logits, dim=-1)

# Map predictions to labels
predictions = predictions.numpy()
df['Classification'] = ['Income' if pred == 1 else 'Expense' for pred in predictions]

# %%
print(df)

# %%
text = "withdraw amount"
# text = "go to hell"
inputs = tokenizer(text,padding = True, truncation = True, return_tensors='pt').to('cuda')
outputs = model(**inputs)
print(outputs)
predictions = torch.nn.functional.softmax(outputs.logits, dim=-1)
print(predictions)
predictions = predictions.cpu().detach().numpy()
predictions
